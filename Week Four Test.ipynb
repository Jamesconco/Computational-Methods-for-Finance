# %%
import numpy as np
def square(x):
   return x * x
x = 3
y = square(x)
print('%d square is %d' % (x,y))
# Out:
# 3 square is 9

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10,100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %%
a = 10
type(a)
# Out:
# int

# %%
a.bit_length()
# Out:
# 4
